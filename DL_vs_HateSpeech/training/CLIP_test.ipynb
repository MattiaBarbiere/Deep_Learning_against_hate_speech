# %%
# Automatically reload modules
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from DL_vs_HateSpeech.CLIP.clip import FineTunedCLIP
from DL_vs_HateSpeech.loading_data.dataloader import DataLoader

# %%
train_loader = DataLoader(type="train")
image, text, label = next(iter(train_loader))
print(image.shape)
import matplotlib.pyplot as plt
print(image.dtype)
plt.imshow(image.permute(1, 2, 0))
# Out:
# torch.Size([3, 640, 600])
# torch.uint8

# %%
clip = FineTunedCLIP(model_type=16)
tokens= clip(text, image)
print(tokens.shape)
# Out:
# torch.Size([1, 223, 512])
